# %%
from numpy import loadtxt
from keras.models import load_model
from keras.utils.vis_utils import plot_model
import h5py
import chess
import chess.engine

# %%
adams_file = "/Users/zoepratt/Documents/GitHub/Top-Chess-Players/code/adams/adams.h5"
adams = load_model(adams_file)

carlsen_file = "/Users/zoepratt/Documents/GitHub/Top-Chess-Players/code/carlsen/carlsen.h5"
carlsen = load_model(carlsen_file)

# %%
engine = chess.engine.SimpleEngine.popen_uci(r"/Users/zoepratt/Documents/GitHub/Top-Chess-Players/code/carlsen/carlsen.h5")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-32-7e3bffdb7074> in <module>
# ----> 1 engine = chess.engine.SimpleEngine.popen_uci(r"/Users/zoepratt/Documents/GitHub/Top-Chess-Players/code/carlsen/carlsen.h5")
#       2
#
# /opt/anaconda3/lib/python3.8/site-packages/chess/engine.py in popen_uci(cls, command, timeout, debug, setpgrp, **popen_args)
#    2822         Returns a :class:`~chess.engine.SimpleEngine` instance.
#    2823         """
# -> 2824         return cls.popen(UciProtocol, command, timeout=timeout, debug=debug, setpgrp=setpgrp, **popen_args)
#    2825
#    2826     @classmethod
#
# /opt/anaconda3/lib/python3.8/site-packages/chess/engine.py in popen(cls, Protocol, command, timeout, debug, setpgrp, **popen_args)
#    2814             await simple_engine.shutdown_event.wait()
#    2815
# ...

# %%
import random

flatten = lambda l: [item for sublist in l for item in sublist]
instance = random.randint(1,len(X)-1)
state = X[instance].reshape(1,8,8,13)
action = carlsen.predict(state)[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-dcd6b2989bf1> in <module>
#       2
#       3 flatten = lambda l: [item for sublist in l for item in sublist]
# ----> 4 instance = random.randint(1,len(X)-1)
#       5 state = X[instance].reshape(1,8,8,13)
#       6 action = carlsen.predict(state)[1]
#
# NameError: name 'X' is not defined

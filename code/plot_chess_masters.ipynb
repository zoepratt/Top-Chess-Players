# %%
# %matplotlib inline

# %% [markdown]
# # Chess Masters
#
# An example of the MultiDiGraph class.
#
# The function `chess_pgn_graph` reads a collection of chess matches stored in
# the specified PGN file (PGN ="Portable Game Notation").  Here the (compressed)
# default file::
#
#     chess_masters_WCC.pgn.bz2
#
# contains all 685 World Chess Championship matches from 1886--1985.
# (data from http://chessproblem.my-free-games.com/chess/games/Download-PGN.php)
#
# The `chess_pgn_graph()` function returns a `MultiDiGraph` with multiple edges.
# Each node is the last name of a chess master. Each edge is directed from white
# to black and contains selected game info.
#
# The key statement in `chess_pgn_graph` below is::
#
#     G.add_edge(white, black, game_info)
#
# where `game_info` is a `dict` describing each game.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import os
import os.path


# tag names specifying what game info should be
# stored in the dict on each digraph edge
game_details = ["Event", "Date", "Result", "ECO", "Site"]

pgn = open("/Users/zoepratt/Documents/GitHub/Top-Chess-Players/data/test_Adams.pgn")

def chess_pgn_graph(pgn_file):
    """Read chess games in pgn format in pgn_file.

    Filenames ending in .bz2 will be uncompressed.

    Return the MultiDiGraph of players connected by a chess game.
    Edges contain game data in a dict.

    """
    import bz2

    G = nx.MultiDiGraph()
    game = {}
    with pgn_file as datafile:
        lines = [line.rstrip("\r\n") for line in datafile]
    for line in lines:
        if line.startswith("["):
            tag, value = line[1:-1].split(" ", 1)
            game[str(tag)] = value.strip('"')
        else:
            # empty line after tag set indicates
            # we finished reading game info
            if game:
                white = game.pop("White")
                black = game.pop("Black")
                G.add_edge(white, black, **game)
                game = {}
    return G


G = chess_pgn_graph(pgn)

print(
    f"Loaded {G.number_of_edges()} chess games between {G.number_of_nodes()} players\n"
)

# identify connected components of the undirected version
H = G.to_undirected()
Gcc = [H.subgraph(c) for c in nx.connected_components(H)]
if len(Gcc) > 1:
    print(f"Note the disconnected component consisting of:\n{Gcc[1].nodes()}")

# find all games with B97 opening (as described in ECO)
openings = {game_info["ECO"] for (white, black, game_info) in G.edges(data=True)}
print(f"\nFrom a total of {len(openings)} different openings,")
print("the following games used the Sicilian opening")
print('with the Najdorff 7...Qb6 "Poisoned Pawn" variation.\n')

for (white, black, game_info) in G.edges(data=True):
    if game_info["ECO"] == "B97":
        summary = f"{white} vs {black}\n"
        for k, v in game_info.items():
            summary += f"   {k}: {v}\n"
        summary += "\n"
        print(summary)

# make new undirected graph H without multi-edges
H = nx.Graph(G)

# edge width is proportional number of games played
edgewidth = [len(G.get_edge_data(u, v)) for u, v in H.edges()]

# node size is proportional to number of games won
wins = dict.fromkeys(G.nodes(), 0.0)
for (u, v, d) in G.edges(data=True):
    r = d["Result"].split("-")
    if r[0] == "1":
        wins[u] += 1.0
    elif r[0] == "1/2":
        wins[u] += 0.5
        wins[v] += 0.5
    else:
        wins[v] += 1.0
nodesize = [wins[v] * 50 for v in H]

# Generate layout for visualization
pos = nx.kamada_kawai_layout(H)
# Manual tweaking to limit node label overlap in the visualization
pos["Reshevsky, Samuel H"] += (0.05, -0.10)
pos["Botvinnik, Mikhail M"] += (0.03, -0.06)
pos["Smyslov, Vassily V"] += (0.05, -0.03)

fig, ax = plt.subplots(figsize=(12, 12))
# Visualize graph components
nx.draw_networkx_edges(H, pos, alpha=0.3, width=edgewidth, edge_color="m")
nx.draw_networkx_nodes(H, pos, node_size=nodesize, node_color="#210070", alpha=0.9)
label_options = {"ec": "k", "fc": "white", "alpha": 0.7}
nx.draw_networkx_labels(H, pos, font_size=14, bbox=label_options)

# Title/legend
font = {"fontname": "Helvetica", "color": "k", "fontweight": "bold", "fontsize": 14}
ax.set_title("World Chess Championship Games: 1886 - 1985", font)
# Change font color for legend
font["color"] = "r"

ax.text(
    0.80,
    0.10,
    "edge width = # games played",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)
ax.text(
    0.80,
    0.06,
    "node size = # games won",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)

# Resize figure for label readibility
ax.margins(0.1, 0.05)
fig.tight_layout()
plt.axis("off")
plt.show()
# Out:
# Loaded 3331 chess games between 1129 players
#
# Note the disconnected component consisting of:
# ['Adams,Mi', 'Arkell,K', "O'Cinneide,M", 'Bellin,R', 'Hebden,M', 'McShane,L', 'Baburin,A', 'Lalic,B', 'Ftacnik,L', 'Speelman,J', 'Kramnik,V', 'Polgar,Ju', 'Korchnoi,V', 'Kasparov,G', 'Van Wely,L', 'Piket,Je', 'Morozevich,A', 'Short,N', 'Anand,V', 'Lputian,S', 'Timman,J', 'Nikolic,Pr', 'Leko,P', 'Seirawan,Y', 'Gulko,B', 'Deep Junior', 'Liiva,R', 'Soza,J', 'Zarnicki,P', 'Kogan,A', 'Van de Mortel,J', 'Visser,Y', 'Fressinet,L', 'Lautier,J', 'King,D', 'Emms,J', 'Rowson,J', 'Shirov,A', 'Georgiev,Ki', 'Movsesian,S', 'Bacrot,E', 'Bareev,E', 'Gurevich,M', 'Topalov,V', 'Sokolov,I', 'Hoffmann,M', 'Ljubojevic,L', 'Ivanchuk,V', 'Rabiega,R', 'Rublevsky,S', 'Jussupow,A', 'DEEP JUNIOR 6', 'Huebner,R', 'Khalifman,A', 'Akopian,V', 'Huzman,A', 'Motylev,A', 'Stohl,I', 'Muse,M', 'Adhami,V', 'Gonzalez,Bernal', 'Hansen,Cu', 'Morovic Fernandez,I', 'Krasenkow,M', 'Stefansson,H', 'Milos,G', 'Papaioannou,I', 'Dao Thien Hai', 'Yermolinsky,A', 'Svidler,P', 'Fedorov,Alex', 'Tiviakov,S', 'Mellado Trivino,J', 'Leski,M', 'Kishnev,S', 'Tkachiev,V', 'Kasimdzhanov,R', 'Hamdouchi,H', 'Ye Jiangchuan', 'Legky,N', 'Ward,C', 'Chandler,M', 'Hodgson,Ju', 'Kallai,G', 'Koch,JR', 'Bezold,M', 'Bonnaire,Ulrich', 'Pomes Marcet,J', 'POCKET FRITZ', 'Hennigan,M', 'Conquest,S', 'Vega Holm,F', 'Narciso Dublan,M', 'Campos Moreno,J', 'Paramos Dominguez,R', 'Garcia Ilundain,D', 'Rojo Gomez,J', 'Vassallo,M', 'Kengis,E', 'Kozul,Z', 'Milov,V', 'Lutz,C', 'Beliavsky,A', 'Sarthou,G', 'Kobalija,M', 'Zvjaginsev,V', 'Grischuk,A', 'Gelfand,B', 'Dreev,A', 'Ponomariov,R', 'Vallejo Pons,F', 'Skripchenko,A', 'Radjabov,T', 'Bistric,F', 'Feletar,D', 'Nikolac,J', 'Damljanovic,B', 'Banikas,H', 'Romanishin,O', 'Sakaev,K', 'Borovikov,V', 'Prusikhin,M', 'Khenkin,I', 'Rozentalis,E', 'Torre,E', 'Valenzuela Fuentealba,L', 'Aleksandrov,A', 'Sasikiran,K', 'Cobb,J', 'Littlewood,P', 'Macieja,B', 'Parker,J', 'Quinn,M', 'Nguyen Chi Minh', 'Kosten,A', 'Komarov,D', 'Breder,D', 'Gretarsson,H', 'Kristjansson,S', 'Bergsson,S', 'Cmilyte,V', 'Sutovsky,E', 'Tregubov,P', 'Hjartarson,J', 'Buhmann,R', 'Mullon,J', 'Bologan,V', 'Cornette,M', 'Pert,N', 'Haslinger,S', 'Baklan,V', 'Agrest,E', 'Gallagher,Jo', 'Saiboulatov,D', 'Sokolov,And', 'Bauer,Ch', 'Akopian,Vl', 'Rasik,V', 'Babula,V', 'Zhigalko,S', 'Kobalia,M', 'Avrukh,B', 'Azmaiparashvili,Z', 'Dovramadjiev,T', 'Hansen,SuB', 'Nunn,J', 'Zhang Zhong', 'Hernandez,Gi', 'Galdunts,S', 'Philippe,C', 'Santo Roman,M', 'Woodward,T', 'Vaganian,R', 'Asabri,Hu', 'Asrian,K', 'Nakamura,H', 'Maki Uuro,Mi', 'Fejzullahu,A', 'Kurajica,B', 'Haznedaroglu,K', 'Charbonneau,P', 'Almasi,Z', 'Megaranto,S', 'Rogers,I', 'Mitkov,N', 'Jakovenko,D', 'Psakhis,L', 'Nielsen,PH', 'Kosyrev,V', 'Ovetchkin,R', 'Turov,M', 'Dobrov,V', 'Shipov,S', 'Kharlov,A', 'Vlassov,N', 'Panarin,M', 'Bruzon,L', 'Slobodjan,R', 'Rocha,S', 'Pelletier,Y', 'Gyimesi,Z', 'Bates,Ri', 'Jussupow,Ar', 'Vaisser,A', 'Kazhgaleyev,M', 'HYDRA', 'Naiditsch,A', 'Riazantsev,A', 'Karjakin,Sergey', 'Aronian,L', 'Kamsky,G', 'Sokolov,Iv', 'Mamedyarov,S', 'Cardon,H', 'Nisipeanu,LD', 'Gashimov,V', 'Gregoire,S', 'Johannessen,LE', 'Davies,Ni', 'Nikolaidis,I', 'Annaberdiev,M', 'Adianto,U', 'Kozlov,R', 'Granda Zuniga,J', 'Carlsen,M', 'Gonzalez Zamora,J', 'Ghaem Maghami,E', 'Sedlak,N', 'Jobava,Ba', 'Howell,D', 'Werle,J', 'Bosboom Lanchava,T', 'Wells,P', 'Day,L', 'Levitt,J', "L'Ami,E", 'Landa,K', 'Heidenfeld,M', 'Atlas,V', 'Paehtz,E', 'Caruana,F', 'Greenfeld,A', 'Roiz,M', 'Epishin,V', 'Efimenko,Z', 'Sandipan,C', 'Al Modiahki,M', 'Feller,S', 'Wojtaszek,R', 'Miroshnichenko,E', 'Socko,B', 'Smeets,J', 'Houska,Jo', 'Jones,G', 'McNab,C', 'Sokolov,Iv NED', 'Wang Yue', 'Bu Xiangzhi', 'Ni Hua', 'Zhang Pengxiang', 'Wang Hao', 'Hou Yifan', 'Ogaard,L', 'Smirin,I', 'Kempinski,R', 'Tomashevsky,E', 'Alekseev,Evgeny', 'Navara,D', 'Nyback,T', 'Berg,E', 'Karpov,Ana', 'Korotylev,A', 'Savchenko,B', 'Zugic,I', 'Zhou Jianchao', 'Eljanov,P', 'Koneru,H', 'Perez Candelario,Man', 'Sargissian,G', 'Cheparinov,I', 'Inarkiev,E', 'Wade,R', 'Cherniaev,A1', 'Graf,A', 'Mamedov,Rau', 'Illescas ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-f67c6d05a718> in <module>
#      54
#      55 # find all games with B97 opening (as described in ECO)
# ---> 56 openings = {game_info["ECO"] for (white, black, game_info) in G.edges(data=True)}
#      57 print(f"\nFrom a total of {len(openings)} different openings,")
#      58 print("the following games used the Sicilian opening")
#
# <ipython-input-17-f67c6d05a718> in <setcomp>(.0)
#      54
#      55 # find all games with B97 opening (as described in ECO)
# ---> 56 openings = {game_info["ECO"] for (white, black, game_info) in G.edges(data=True)}
#      57 print(f"\nFrom a total of {len(openings)} different openings,")
#      58 print("the following games used the Sicilian opening")
#
# KeyError: 'ECO'

# %%
# identify connected components of the undirected version
H = G.to_undirected()
Gcc = [H.subgraph(c) for c in nx.connected_components(H)]
if len(Gcc) > 1:
    print(f"Note the disconnected component consisting of:\n{Gcc[1].nodes()}")

# find all games with B97 opening (as described in ECO)
openings = {game_info["ECO"] for (white, black, game_info) in G.edges(data=True)}
print(f"\nFrom a total of {len(openings)} different openings,")
print("the following games used the Sicilian opening")
print('with the Najdorff 7...Qb6 "Poisoned Pawn" variation.\n')

for (white, black, game_info) in G.edges(data=True):
    if game_info["ECO"] == "B97":
        summary = f"{white} vs {black}\n"
        for k, v in game_info.items():
            summary += f"   {k}: {v}\n"
        summary += "\n"
        print(summary)

# make new undirected graph H without multi-edges
H = nx.Graph(G)

# edge width is proportional number of games played
edgewidth = [len(G.get_edge_data(u, v)) for u, v in H.edges()]

# node size is proportional to number of games won
wins = dict.fromkeys(G.nodes(), 0.0)
for (u, v, d) in G.edges(data=True):
    r = d["Result"].split("-")
    if r[0] == "1":
        wins[u] += 1.0
    elif r[0] == "1/2":
        wins[u] += 0.5
        wins[v] += 0.5
    else:
        wins[v] += 1.0
nodesize = [wins[v] * 50 for v in H]

# Generate layout for visualization
pos = nx.kamada_kawai_layout(H)
# Manual tweaking to limit node label overlap in the visualization
pos["Reshevsky, Samuel H"] += (0.05, -0.10)
pos["Botvinnik, Mikhail M"] += (0.03, -0.06)
pos["Smyslov, Vassily V"] += (0.05, -0.03)

fig, ax = plt.subplots(figsize=(12, 12))
# Visualize graph components
nx.draw_networkx_edges(H, pos, alpha=0.3, width=edgewidth, edge_color="m")
nx.draw_networkx_nodes(H, pos, node_size=nodesize, node_color="#210070", alpha=0.9)
label_options = {"ec": "k", "fc": "white", "alpha": 0.7}
nx.draw_networkx_labels(H, pos, font_size=14, bbox=label_options)

# Title/legend
font = {"fontname": "Helvetica", "color": "k", "fontweight": "bold", "fontsize": 14}
ax.set_title("World Chess Championship Games: 1886 - 1985", font)
# Change font color for legend
font["color"] = "r"

ax.text(
    0.80,
    0.10,
    "edge width = # games played",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)
ax.text(
    0.80,
    0.06,
    "node size = # games won",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)

# Resize figure for label readibility
ax.margins(0.1, 0.05)
fig.tight_layout()
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-3cdebe6eed97> in <module>
#      37
#      38
# ---> 39 G = chess_pgn_graph()
#      40
#      41 print(
#
# <ipython-input-6-3cdebe6eed97> in chess_pgn_graph(pgn_file)
#      21     game = {}
#      22     with bz2.BZ2File(pgn_file) as datafile:
# ---> 23         lines = [line.decode().rstrip("\r\n") for line in datafile]
#      24     for line in lines:
#      25         if line.startswith("["):
#
# <ipython-input-6-3cdebe6eed97> in <listcomp>(.0)
#      21     game = {}
#      22     with bz2.BZ2File(pgn_file) as datafile:
# ---> 23         lines = [line.decode().rstrip("\r\n") for line in datafile]
#      24     for line in lines:
#      25         if line.startswith("["):
#
# /opt/anaconda3/lib/python3.8/bz2.py in readline(self, size)
#     217         with self._lock:
#     218             self._check_can_read()
# --> 219             return self._buffer.readline(size)
#     220
#     221     def readlines(self, size=-1):
#
# /opt/anaconda3/lib/python3.8/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /opt/anaconda3/lib/python3.8/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# OSError: Invalid data stream
